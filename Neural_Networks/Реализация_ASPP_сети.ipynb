# %% [markdown]
# # Реализация ASPP сети
# Cоздадим еще еще одну сегментационную FCN модель на основе блока ASPP (Atrous Spatial Pyramid Pooling), который основан на дилатационных свёртках (Atrous Conv, Dilated Conv)

# %% [markdown]
# ### Загрузка необходимых библиотек
# Здесь мы загружаем различне библиотеки, включая TensoFlow.

# %%
import numpy as np

import tensorflow as tf

print('TensorFlow version:', tf.__version__)
# Out:
# TensorFlow version: 2.6.0

# %% [markdown]
# ### Создание ASPP модели
# Cоздана модель `ASPPNet` через собственный класс, наследованный от `tf.keras.Model`. Использовать возможность модульного создания нейросетей. Сначала создадим отдельно модель для ASPP блока (блок, который содержит только дилатационные свёртки и применяется между энкодером и декодером), которая по сути будет являться самостоятельным слоем. А затем создаем модель `ASPPNet`, в который `ASPPBlock` будет использоваться как слой между Энкодером и Декодером.
#
# В ASPP блоке (`ASPPBlock`) ко входному тензору параллельно применяются обычная свёртка 1x1 и несколько дилатационных свёрток. Затем все эти резульаты конкатенируются. Далее "перемешиваем" каналы полученного тензора с помощью еще одной свёртки 1x1.
#
# В финальной ASPP модели (`ASPPNet`) в качестве Энкодера будем использовать стандартные свёртки и пулинги. Далее в боттлнеке применим слой ASPPBlock. А в Декодере будем использовать более простую архитектуру: меньше свёрток, повышение размерности с помощью двух билинейных интерполяций (`tf.image.resize`). Кроме того, в сети присутствуют две проброшенные связи.

# %%
class ASPPBlock(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.conv1 = tf.keras.layers.Conv2D(256, (1, 1), padding='same', activation='relu')
        self.conv2 = tf.keras.layers.Conv2D(256, (3, 3), dilation_rate=6, padding='same', activation='relu')
        self.conv3 = tf.keras.layers.Conv2D(256, (3, 3), dilation_rate=12, padding='same', activation='relu')
        self.conv4 = tf.keras.layers.Conv2D(256, (3, 3), dilation_rate=18, padding='same', activation='relu')
        self.conv5 = tf.keras.layers.Conv2D(256, (1, 1), padding='same', activation='relu')

    def call(self, inp, is_training=False):
        out1 = self.conv1(inp)
        out2 = self.conv2(inp)
        out3 = self.conv3(inp)
        out4 = self.conv4(inp)
        out = tf.concat([out1, out2, out3, out4], axis=3)
        out = self.conv5(out)
        return out
    
class ASPPNet(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.conv1 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        self.conv2 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        self.conv3 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        self.conv4 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        self.conv5 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        self.conv6 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        self.conv7 = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')
        self.conv8 = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')
        self.conv9 = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')
        self.conv10 = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')

        self.conv11 = tf.keras.layers.Conv2D(48, (1, 1), padding='same', activation='relu')
        self.conv12 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        self.conv13 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        self.conv14 = tf.keras.layers.Conv2D(1, (1, 1), padding='same', activation=None)

        self.maxpool = tf.keras.layers.MaxPooling2D((2, 2), (2, 2), padding='same')

        self.aspp = ASPPBlock()

    def call(self, x):

        out = self.conv1(x)
        out = self.conv2(out)
        out = self.maxpool(out)
        out = self.conv3(out)
        out = self.conv4(out)
        out = self.maxpool(out)
        out = self.conv5(out)
        out = self.conv6(out)
        out_enc_mid = out
        out = self.maxpool(out)
        out = self.conv7(out)
        out = self.conv8(out)
        out = self.maxpool(out)
        out = self.conv9(out)
        out = self.conv10(out)

        out = self.aspp(out)

        out = tf.image.resize(out, tf.shape(out_enc_mid)[1:3], tf.image.ResizeMethod.BILINEAR)

        out_enc_mid = self.conv11(out_enc_mid)

        out = tf.concat([out, out_enc_mid], axis=3)

        out = self.conv12(out)
        out = self.conv13(out)
        out = self.conv14(out)

        out = tf.image.resize(out, tf.shape(x)[1:3], tf.image.ResizeMethod.BILINEAR)
        out = tf.nn.sigmoid(out)
        return out
    
model = ASPPNet()

# %% [markdown]
# ### Задания

# %% [markdown]
# Реализуйте пайплайн обучения для модели ASPPNet: подготовка данных, лосс, обучение, тестирование. Используйте материалы из предыдущего практического урока. Обучите модель и сравните время обучения с временем обучения более простых версий FCN из предыдущих уроков.

# %%
import random
import imageio
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt


img = imageio.imread('sample_data/me_256.png')
img = img.astype(np.float32) / 255.
_=plt.imshow(img)

# %%
gt = imageio.imread('sample_data/me_gt_256.png')
gt = gt.astype(np.float32) / 255.
gt = np.mean(gt, axis=2)[...,None]
_=plt.imshow(gt[...,0])

# %%
train_x = np.stack((img, img[:,::-1,:]))
train_y = np.stack((gt, gt[:,::-1,:]))

plt.imshow(train_x[0]), plt.show()
plt.imshow(train_y[0][...,0]), plt.show()
plt.imshow(train_x[1]), plt.show()
plt.imshow(train_y[1][...,0]), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7fe09410f490>, None)

# %%
NUM_EPOCHS = 100

loss = tf.keras.losses.BinaryCrossentropy()
model.compile(optimizer='adam', loss=loss)

# %%
history = model.fit(train_x, train_y, batch_size=1, epochs=NUM_EPOCHS)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 8s 3s/step - loss: 0.6804
# Epoch 2/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.6657
# Epoch 3/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.7009
# Epoch 4/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.5710
# Epoch 5/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.5677
# Epoch 6/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.4011
# Epoch 7/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.3136
# Epoch 8/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.2475
# Epoch 9/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.2293
# Epoch 10/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.1853
# Epoch 11/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.1669
# Epoch 12/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.1340
# Epoch 13/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.1104
# Epoch 14/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.1061
# Epoch 15/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.1034
# Epoch 16/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0934
# Epoch 17/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0912
# Epoch 18/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0916
# Epoch 19/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0852
# Epoch 20/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0822
# Epoch 21/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0791
# Epoch 22/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0771
# Epoch 23/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0754
# Epoch 24/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0679
# Epoch 25/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0644
# Epoch 26/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0555
# Epoch 27/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0581
# Epoch 28/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0575
# Epoch 29/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0583
# Epoch 30/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0621
# Epoch 31/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0524
# Epoch 32/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0442
# Epoch 33/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0417
# Epoch 34/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0392
# Epoch 35/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0353
# Epoch 36/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0298
# Epoch 37/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0266
# Epoch 38/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0250
# Epoch 39/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0275
# Epoch 40/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0247
# Epoch 41/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0248
# Epoch 42/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0253
# Epoch 43/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0244
# Epoch 44/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0278
# Epoch 45/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0216
# Epoch 46/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0220
# Epoch 47/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0193
# Epoch 48/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0193
# Epoch 49/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0218
# Epoch 50/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0177
# Epoch 51/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0201
# Epoch 52/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0187
# Epoch 53/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0163
# Epoch 54/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0167
# Epoch 55/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0168
# Epoch 56/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0209
# Epoch 57/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0218
# Epoch 58/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0296
# Epoch 59/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0265
# Epoch 60/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0283
# Epoch 61/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0205
# Epoch 62/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0269
# Epoch 63/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0212
# Epoch 64/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0188
# Epoch 65/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0184
# Epoch 66/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0182
# Epoch 67/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0138
# Epoch 68/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0157
# Epoch 69/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0134
# Epoch 70/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0122
# Epoch 71/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0124
# Epoch 72/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0125
# Epoch 73/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0113
# Epoch 74/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0102
# Epoch 75/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0119
# Epoch 76/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0103
# Epoch 77/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0090
# Epoch 78/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0088
# Epoch 79/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0085
# Epoch 80/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0085
# Epoch 81/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0080
# Epoch 82/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0081
# Epoch 83/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0088
# Epoch 84/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0077
# Epoch 85/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0074
# Epoch 86/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0102
# Epoch 87/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0088
# Epoch 88/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0084
# Epoch 89/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0076
# Epoch 90/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0071
# Epoch 91/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0069
# Epoch 92/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0068
# Epoch 93/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0068
# Epoch 94/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0066
# Epoch 95/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0064
# Epoch 96/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0063
# Epoch 97/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0061
# Epoch 98/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0062
# Epoch 99/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0063
# Epoch 100/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0060

# %%
plt.plot(history.history['loss'])

# %%
out = model.predict(img[None, ...])
_=plt.imshow(out[0, ..., 0])

# %%
for sample in train_x:
    out = model.predict(sample[None, ...])
    seg_map = (out[0, ..., 0]>0.5).astype(np.float32)
    seg_map_clr = plt.get_cmap('jet')(seg_map)[..., :3]
    plt.imshow(sample*0.5 + seg_map_clr*0.5)
    plt.show()
