# %% [markdown]
# # Реализация обучения FCN

# %% [markdown]
# ### Загрузка необходимых библиотек

# %%
import random
import imageio
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

import tensorflow as tf

print('TensorFlow version:', tf.__version__)
# Out:
# TensorFlow version: 2.6.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Подготовка датасета

# %% [markdown]
# ### Загрузка и подготовка входного изображения

# %%
img = imageio.imread('sample_data/me_256.png')
img = img.astype(np.float32) / 255.
_=plt.imshow(img)

# %% [markdown]
# ### Загрузка и подготовка карты сегментации человек/фон

# %%
gt = imageio.imread('sample_data/me_gt_256.png')
gt = gt.astype(np.float32) / 255.
gt = np.mean(gt, axis=2)[...,None]
_=plt.imshow(gt[...,0])

# %% [markdown]
# ### Подготовка обучающего датасета
# Наша цель создать пайплайн для обучения, включая данные, модель, лосс и т.д.
#
# Поэтому для простоты возьмем очень простой датасет, состоящий из двух изображений: загруженная картинка и её зеркально отраженная копия.
#
# При обучении на таком маленьком датасете модель переобучится, но в данном примере нас это не будет беспокоить. Наша цель - отладить пайплайн, поэтому тестировать будем на том же, на чём и обучались

# %%
train_x = np.stack((img, img[:,::-1,:]))
train_y = np.stack((gt, gt[:,::-1,:]))

plt.imshow(train_x[0]), plt.show()
plt.imshow(train_y[0][...,0]), plt.show()
plt.imshow(train_x[1]), plt.show()
plt.imshow(train_y[1][...,0]), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7fa0cf187690>, None)

# %% [markdown]
# # Пайплайн обучения FCN

# %% [markdown]
# ### Создание FCN модели
# Модель создаётся путём наслелования от `tf.keras.Model`.
#
# В методе `Model.__init__` создаются слои.
#
# В методе `Model.call` производится инференс с использованием созданных слоёв и других функций TensorFlow

# %%
class Model(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.conv1 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        self.conv2 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        self.conv3 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        self.conv4 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        self.conv5 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        self.conv6 = tf.keras.layers.Conv2D(1, (3, 3), padding='same', activation=None)
        self.pool = tf.keras.layers.MaxPool2D((2, 2))
        
    def call(self, x):
        out = self.conv1(x)
        out = self.conv2(out)
        out = self.pool(out)
        out = self.conv3(out)
        out = self.conv4(out)
        out = self.pool(out)
        out = self.conv5(out)
        out = self.conv6(out)
        out = tf.image.resize(out, (x.shape[1], x.shape[2]), tf.image.ResizeMethod.BILINEAR)
        out = tf.nn.sigmoid(out)
        return out
    
model = Model()

# %% [markdown]
# ### Параметры обучения

# %%
NUM_EPOCHS = 100

# %% [markdown]
# ### Подготовка модели к обучению
# В качестве лосса используется бинарная кросс-энтропия (BinaryCrossentropy).
# В лоссе автоматически происходит суммирование по всем измерениям.

# %%
loss = tf.keras.losses.BinaryCrossentropy()
model.compile(optimizer='adam', loss=loss)

# %% [markdown]
# ### Обучение модели

# %%
history = model.fit(train_x, train_y, batch_size=1, epochs=NUM_EPOCHS)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.6865
# Epoch 2/100
# 2/2 [==============================] - 2s 969ms/step - loss: 0.6603
# Epoch 3/100
# 2/2 [==============================] - 2s 983ms/step - loss: 0.5991
# Epoch 4/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.4476
# Epoch 5/100
# 2/2 [==============================] - 2s 985ms/step - loss: 0.3421
# Epoch 6/100
# 2/2 [==============================] - 2s 973ms/step - loss: 0.2802
# Epoch 7/100
# 2/2 [==============================] - 2s 978ms/step - loss: 0.2280
# Epoch 8/100
# 2/2 [==============================] - 2s 968ms/step - loss: 0.2374
# Epoch 9/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.2209
# Epoch 10/100
# 2/2 [==============================] - 2s 980ms/step - loss: 0.2163
# Epoch 11/100
# 2/2 [==============================] - 2s 964ms/step - loss: 0.2126
# Epoch 12/100
# 2/2 [==============================] - 2s 989ms/step - loss: 0.2117
# Epoch 13/100
# 2/2 [==============================] - 2s 985ms/step - loss: 0.2084
# Epoch 14/100
# 2/2 [==============================] - 2s 975ms/step - loss: 0.2034
# Epoch 15/100
# 2/2 [==============================] - 2s 991ms/step - loss: 0.2008
# Epoch 16/100
# 2/2 [==============================] - 2s 953ms/step - loss: 0.1959
# Epoch 17/100
# 2/2 [==============================] - 2s 978ms/step - loss: 0.1915
# Epoch 18/100
# 2/2 [==============================] - 2s 966ms/step - loss: 0.1855
# Epoch 19/100
# 2/2 [==============================] - 2s 973ms/step - loss: 0.1794
# Epoch 20/100
# 2/2 [==============================] - 2s 991ms/step - loss: 0.1695
# Epoch 21/100
# 2/2 [==============================] - 2s 1000ms/step - loss: 0.1558
# Epoch 22/100
# 2/2 [==============================] - 2s 965ms/step - loss: 0.1234
# Epoch 23/100
# 2/2 [==============================] - 2s 976ms/step - loss: 0.1972
# Epoch 24/100
# 2/2 [==============================] - 2s 976ms/step - loss: 0.0775
# Epoch 25/100
# 2/2 [==============================] - 2s 953ms/step - loss: 0.1022
# Epoch 26/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.2226
# Epoch 27/100
# 2/2 [==============================] - 2s 957ms/step - loss: 0.3168
# Epoch 28/100
# 2/2 [==============================] - 2s 966ms/step - loss: 0.1398
# Epoch 29/100
# 2/2 [==============================] - 2s 983ms/step - loss: 0.1965
# Epoch 30/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.1899
# Epoch 31/100
# 2/2 [==============================] - 2s 994ms/step - loss: 0.1541
# Epoch 32/100
# 2/2 [==============================] - 2s 977ms/step - loss: 0.1527
# Epoch 33/100
# 2/2 [==============================] - 2s 983ms/step - loss: 0.1558
# Epoch 34/100
# 2/2 [==============================] - 2s 965ms/step - loss: 0.1380
# Epoch 35/100
# 2/2 [==============================] - 2s 997ms/step - loss: 0.1152
# Epoch 36/100
# 2/2 [==============================] - 2s 990ms/step - loss: 0.1039
# Epoch 37/100
# 2/2 [==============================] - 2s 963ms/step - loss: 0.0820
# Epoch 38/100
# 2/2 [==============================] - 2s 972ms/step - loss: 0.0629
# Epoch 39/100
# 2/2 [==============================] - 2s 971ms/step - loss: 0.0460
# Epoch 40/100
# 2/2 [==============================] - 2s 984ms/step - loss: 0.0461
# Epoch 41/100
# 2/2 [==============================] - 2s 981ms/step - loss: 0.0432
# Epoch 42/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0492
# Epoch 43/100
# 2/2 [==============================] - 2s 982ms/step - loss: 0.0428
# Epoch 44/100
# 2/2 [==============================] - 2s 949ms/step - loss: 0.0357
# Epoch 45/100
# 2/2 [==============================] - 2s 965ms/step - loss: 0.0354
# Epoch 46/100
# 2/2 [==============================] - 2s 952ms/step - loss: 0.0324
# Epoch 47/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0316
# Epoch 48/100
# 2/2 [==============================] - 2s 957ms/step - loss: 0.0296
# Epoch 49/100
# 2/2 [==============================] - 2s 976ms/step - loss: 0.0283
# Epoch 50/100
# 2/2 [==============================] - 2s 970ms/step - loss: 0.0259
# Epoch 51/100
# 2/2 [==============================] - 2s 951ms/step - loss: 0.0254
# Epoch 52/100
# 2/2 [==============================] - 2s 959ms/step - loss: 0.0248
# Epoch 53/100
# 2/2 [==============================] - 2s 984ms/step - loss: 0.0233
# Epoch 54/100
# 2/2 [==============================] - 2s 960ms/step - loss: 0.0223
# Epoch 55/100
# 2/2 [==============================] - 2s 986ms/step - loss: 0.0222
# Epoch 56/100
# 2/2 [==============================] - 2s 971ms/step - loss: 0.0214
# Epoch 57/100
# 2/2 [==============================] - 2s 977ms/step - loss: 0.0199
# Epoch 58/100
# 2/2 [==============================] - 2s 970ms/step - loss: 0.0184
# Epoch 59/100
# 2/2 [==============================] - 2s 985ms/step - loss: 0.0182
# Epoch 60/100
# 2/2 [==============================] - 2s 953ms/step - loss: 0.0251
# Epoch 61/100
# 2/2 [==============================] - 2s 980ms/step - loss: 0.0251
# Epoch 62/100
# 2/2 [==============================] - 2s 945ms/step - loss: 0.0268
# Epoch 63/100
# 2/2 [==============================] - 2s 961ms/step - loss: 0.0233
# Epoch 64/100
# 2/2 [==============================] - 2s 987ms/step - loss: 0.0226
# Epoch 65/100
# 2/2 [==============================] - 2s 956ms/step - loss: 0.0209
# Epoch 66/100
# 2/2 [==============================] - 2s 967ms/step - loss: 0.0193
# Epoch 67/100
# 2/2 [==============================] - 2s 964ms/step - loss: 0.0188
# Epoch 68/100
# 2/2 [==============================] - 2s 994ms/step - loss: 0.0189
# Epoch 69/100
# 2/2 [==============================] - 2s 982ms/step - loss: 0.0184
# Epoch 70/100
# 2/2 [==============================] - 2s 985ms/step - loss: 0.0173
# Epoch 71/100
# 2/2 [==============================] - 2s 974ms/step - loss: 0.0162
# Epoch 72/100
# 2/2 [==============================] - 2s 982ms/step - loss: 0.0159
# Epoch 73/100
# 2/2 [==============================] - 2s 980ms/step - loss: 0.0157
# Epoch 74/100
# 2/2 [==============================] - 2s 959ms/step - loss: 0.0152
# Epoch 75/100
# 2/2 [==============================] - 2s 979ms/step - loss: 0.0144
# Epoch 76/100
# 2/2 [==============================] - 2s 977ms/step - loss: 0.0141
# Epoch 77/100
# 2/2 [==============================] - 2s 968ms/step - loss: 0.0137
# Epoch 78/100
# 2/2 [==============================] - 2s 994ms/step - loss: 0.0133
# Epoch 79/100
# 2/2 [==============================] - 2s 989ms/step - loss: 0.0130
# Epoch 80/100
# 2/2 [==============================] - 2s 991ms/step - loss: 0.0126
# Epoch 81/100
# 2/2 [==============================] - 2s 984ms/step - loss: 0.0124
# Epoch 82/100
# 2/2 [==============================] - 2s 970ms/step - loss: 0.0120
# Epoch 83/100
# 2/2 [==============================] - 2s 970ms/step - loss: 0.0116
# Epoch 84/100
# 2/2 [==============================] - 2s 972ms/step - loss: 0.0115
# Epoch 85/100
# 2/2 [==============================] - 2s 971ms/step - loss: 0.0114
# Epoch 86/100
# 2/2 [==============================] - 2s 980ms/step - loss: 0.0114
# Epoch 87/100
# 2/2 [==============================] - 2s 962ms/step - loss: 0.0112
# Epoch 88/100
# 2/2 [==============================] - 2s 982ms/step - loss: 0.0108
# Epoch 89/100
# 2/2 [==============================] - 2s 976ms/step - loss: 0.0109
# Epoch 90/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0110
# Epoch 91/100
# 2/2 [==============================] - 2s 998ms/step - loss: 0.0111
# Epoch 92/100
# 2/2 [==============================] - 2s 974ms/step - loss: 0.0103
# Epoch 93/100
# 2/2 [==============================] - 2s 972ms/step - loss: 0.0105
# Epoch 94/100
# 2/2 [==============================] - 2s 990ms/step - loss: 0.0107
# Epoch 95/100
# 2/2 [==============================] - 2s 983ms/step - loss: 0.0096
# Epoch 96/100
# 2/2 [==============================] - 2s 989ms/step - loss: 0.0100
# Epoch 97/100
# 2/2 [==============================] - 2s 970ms/step - loss: 0.0096
# Epoch 98/100
# 2/2 [==============================] - 2s 978ms/step - loss: 0.0093
# Epoch 99/100
# 2/2 [==============================] - 2s 990ms/step - loss: 0.0089
# Epoch 100/100
# 2/2 [==============================] - 2s 985ms/step - loss: 0.0087

# %% [markdown]
# ### График зависимости лосса от эпохи

# %%
plt.plot(history.history['loss'])

# %% [markdown]
# ### Результат предсказания на входной картинке

# %%
out = model.predict(img[None, ...])
_=plt.imshow(out[0, ..., 0])

# %% [markdown]
# ### Результат предсказания для всех картинок
# По предсказанию сети получается карта сегментации с помощью порога.
#
# Далее она отображается поверх исходной картинки.

# %%
for sample in train_x:
    out = model.predict(sample[None, ...])
    seg_map = (out[0, ..., 0]>0.5).astype(np.float32)
    seg_map_clr = plt.get_cmap('jet')(seg_map)[..., :3]
    plt.imshow(sample*0.5 + seg_map_clr*0.5)
    plt.show()
